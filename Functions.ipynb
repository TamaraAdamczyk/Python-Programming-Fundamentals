# %%
def calculate_total(a,b): #Parameters(a and b)
    total = a + b         #Task: Addition
    return total          #Output: sum of a and b
result = calculate_total(5,7) #Calling the function with inputs 5 and 7
print(result)             #Output:12
# Out:
# 12

# %%
result2 = calculate_total(6787664,10)
print(result2)
# Out:
# 6787674

# %%
#Built-in function 1: len(): Calculates the length of a sequence or collection - string here
string_length = len("Hello, world!")
len("Hello, world!")
# Out:
# 13

# %%
#Built-in function 1: len(): Calculates the length of a sequence or collection - list here
list_length = len([1, 2, 3, 4, 5])
len([1,2,3,4,5])
# Out:
# 5

# %%
#Built-in function: sum(): Adds up the elements in an iterable (list, tuple, and so on)
total = sum([10, 20, 30, 40, 50])
sum([10,20,30,40,50])
# Out:
# 150

# %%
#Built-in functions: max(): Returns the maximum value in an iterable
highest = max([5, 12, 8, 23, 16])
max([5,12,8,23,16])
# Out:
# 23

# %%
#Built-in functions: min(): Returns the minimum value in an iterable
lowest = min([5, 12, 8, 23, 16])
min([5,12,8,23,16])
# Out:
# 5

# %%
#Pass stetement
def function_name():
    pass

# %%
#Defining function
def greet(name):
    return "Hello, " + name
result = greet("Alice")
print(result)
# Out:
# Hello, Alice

# %%
#Docstrings (Documentation Strings) - Placed inside triple quotes under the function definition
def multiply(a, b):
    """
    This function multiplies two numbers.
    Input: a (number), b (number)
    Output: Product of a and b
    """
    print(a * b)
multiply(2,6)
# Out:
# 12

# %%
def divide(a,b):
    """
    This function divides two numbers.
    Input: a(number), b(number)
    Output: Product of a and b
    """
    print(a/b)
divide(64,8)
# Out:
# 8.0

# %%
#Return statement - gives back a value from a function, ends the function's execution and sends the result, a function can return various types of data
def add(a, b):
    return (a + b)
    
sum_result = add(564, 12)

# %%
def add(a, b):
    return (a + b)
    
add(564, 12)
# Out:
# 576

# %%
sum_result = add(67,67)
print(sum_result)
# Out:
# 134

# %%
global_variable = "I'm global"
def example_function():
    local_variable = "I'm local"
    print(global_variable)  # Accessing global variable
    print(local_variable)   # Accessing local variable - this variable is local to the function and can only be accessed within the function's scope.
print(example_function())
# Out:
# I'm global
# I'm local
# None
